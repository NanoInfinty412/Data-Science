# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# %%
af=pd.read_csv('Pend05degrees.csv')
af.head()
# Out:
#      Time  Angle
# 0  11.965    0.0
# 1  11.966    0.0
# 2  11.967    0.0
# 3  11.969    0.0
# 4  11.970    0.0

# %%
af= af.rename(columns={'Time': 't'})
af= af.rename(columns={'Angle': 'a'})

# %%
af=af[(af.t>18)]
plt.plot(af.t,af.a)
plt.title("Relationship between time and an amplitude of 5")
plt.ylabel("amplitude")
plt.xlabel("period")
plt.grid()

# %%
def sinFit(t,omega,phi,A,offset):
    return A*np.sin(omega*t + phi) + offset

sig=np.ones(len(af))*360.0/2048  # error in angle
T=1.8
omega0 = 2*np.pi/T
A0=-80
phi0=0.0
offset0=0.0

par, cov = curve_fit(sinFit, af.t, af.a, p0=(omega0,phi0,A0,offset0), sigma=sig)

omega,phi,A,offset = par
dOmega, dPhi, dA, dOffset = np.sqrt(np.diag(cov))

plt.plot(af.t, af.a, 'b+')
plt.plot(af.t, sinFit(af.t, omega, phi, A, offset),'r-')
plt.title("Relationship between time and an amplitude of 5")
plt.ylabel("amplitude")
plt.xlabel("period")

print("Omega = %4.4f +/- %4.4f" % (omega, dOmega))
print("phi = %4.2f +/- %4.2f" % (phi, dPhi))
print("A = %4.2f +/- %4.2f" % (A, dA))
print("offset = %4.2f +/- %4.2f" % (offset, dOffset))
# Out:
# Omega = 3.4683 +/- 0.0004
# phi = -0.79 +/- 0.01
# A = -6.02 +/- 0.01
# offset = -0.06 +/- 0.01

# %%
bf=pd.read_csv('Pend10degrees.csv')
bf.head()
# Out:
#     Time  Angle
# 0  3.765    0.0
# 1  3.766    0.0
# 2  3.767    0.0
# 3  3.768    0.0
# 4  3.769    0.0

# %%
bf = bf.rename(columns={'Time': 't'})
bf = bf.rename(columns={'Angle': 'a'})
bf=bf[(bf.t>12)]
plt.plot(bf.t,bf.a)
plt.grid()

# %%
def sinFit(t,omega,phi,A,offset):
    return A*np.sin(omega*t + phi) + offset

sig=np.ones(len(bf))*360.0/2048  # error in angle
T=1.8
omega0 = 2*np.pi/T
A0=70
phi0=0.0
offset0=0.0

par, cov = curve_fit(sinFit, bf.t, bf.a, p0=(omega0,phi0,A0,offset0), sigma=sig)

omega,phi,A,offset = par
dOmega, dPhi, dA, dOffset = np.sqrt(np.diag(cov))

plt.plot(bf.t, bf.a, 'b+')
plt.plot(bf.t, sinFit(bf.t, omega, phi, A, offset),'r-')
plt.title("Relationship between time and an amplitude of 10")
plt.ylabel("amplitude")
plt.xlabel("period")
print("Omega = %4.4f +/- %4.4f" % (omega, dOmega))
print("phi = %4.2f +/- %4.2f" % (phi, dPhi))
print("A = %4.2f +/- %4.2f" % (A, dA))
print("offset = %4.2f +/- %4.2f" % (offset, dOffset))
# Out:
# Omega = 3.4178 +/- 0.0004
# phi = 1.86 +/- 0.01
# A = -28.20 +/- 0.02
# offset = 0.48 +/- 0.02

# %%
cf=pd.read_csv('Pend15degrees.csv')
bf.head()
# Out:
#           t       a
# 576  12.015  25.137
# 577  12.030  24.258
# 578  12.047  23.379
# 579  12.062  22.324
# 580  12.078  21.445

# %%
cf = cf.rename(columns={'Time': 't'})
cf = cf.rename(columns={'Angle': 'a'})
cf=cf[(cf.t>29)]
plt.plot(cf.t,cf.a)
plt.grid()

# %%
def sinFit(t,omega,phi,A,offset):
    return A*np.sin(omega*t + phi) + offset

sig=np.ones(len(cf))*360.0/2048  # error in angle
T=1.8
omega0 = 2*np.pi/T
A0=70
phi0=0.0
offset0=0.0

par, cov = curve_fit(sinFit, cf.t, cf.a, p0=(omega0,phi0,A0,offset0), sigma=sig)

omega,phi,A,offset = par
dOmega, dPhi, dA, dOffset = np.sqrt(np.diag(cov))

plt.plot(cf.t, cf.a, 'b+')
plt.plot(cf.t, sinFit(cf.t, omega, phi, A, offset),'r-')
plt.title("Relationship between time and an amplitude of 15")
plt.ylabel("amplitude")
plt.xlabel("period")
print("Omega = %4.4f +/- %4.4f" % (omega, dOmega))
print("phi = %4.2f +/- %4.2f" % (phi, dPhi))
print("A = %4.2f +/- %4.2f" % (A, dA))
print("offset = %4.2f +/- %4.2f" % (offset, dOffset))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-0a7c6729ad38> in <module>
#       9 offset0=0.0
#      10
# ---> 11 par, cov = curve_fit(sinFit, cf.t, cf.a, p0=(omega0,phi0,A0,offset0), sigma=sig)
#      12
#      13 omega,phi,A,offset = par
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     749         # Remove full_output from kwargs, otherwise we're passing it in twice.
#     750         return_full = kwargs.pop('full_output', False)
# --> 751         res = leastsq(func, p0, Dfun=jac, full_output=1, **kwargs)
#     752         popt, pcov, infodict, errmsg, ier = res
#     753         cost = np.sum(infodict['fvec'] ** 2)
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     384     m = shape[0]
#     385     if n > m:
# --> 386         raise TypeError('Improper input: N=%s must not exceed M=%s' % (n, m))
#     387     if epsfcn is None:
#     388         epsfcn = finfo(dtype).eps
#
# TypeError: Improper input: N=4 must not exceed M=0

# %%
df=pd.read_csv('Pend40degrees.csv')
df.head()
# Out:
#      Time  Angle
# 0  21.511    0.0
# 1  21.512    0.0
# 2  21.513    0.0
# 3  21.514    0.0
# 4  21.515    0.0

# %%
df = df.rename(columns={'Time': 't'})
df = df.rename(columns={'Angle': 'a'})
df=df[(df.t>36.5)]
plt.plot(df.t,df.a)
plt.grid()

# %%
def sinFit(t,omega,phi,A,offset):
    return A*np.sin(omega*t + phi) + offset

sig=np.ones(len(df))*360.0/2048  # error in angle
T=1.8
omega0 = 2*np.pi/T
A0=70
phi0=0.0
offset0=0.0

par, cov = curve_fit(sinFit, df.t, df.a, p0=(omega0,phi0,A0,offset0), sigma=sig)

omega,phi,A,offset = par
dOmega, dPhi, dA, dOffset = np.sqrt(np.diag(cov))

plt.plot(df.t, df.a, 'b+')
plt.plot(df.t, sinFit(df.t, omega, phi, A, offset),'r-')
plt.title("Relationship between time and an amplitude of 10")
plt.ylabel("amplitude")
plt.xlabel("period")
print("Omega = %4.4f +/- %4.4f" % (omega, dOmega))
print("phi = %4.2f +/- %4.2f" % (phi, dPhi))
print("A = %4.2f +/- %4.2f" % (A, dA))
print("offset = %4.2f +/- %4.2f" % (offset, dOffset))
# Out:
# Omega = 3.3621 +/- 0.0001
# phi = 5.15 +/- 0.01
# A = 39.43 +/- 0.02
# offset = 0.66 +/- 0.01

# %%
ef=pd.read_csv('Pend50degrees.csv')
ef.head()
# Out:
#     Time  Angle
# 0  5.765 -0.176
# 1  5.766 -0.176
# 2  5.767 -0.176
# 3  5.768 -0.176
# 4  5.769 -0.176

# %%
ef = ef.rename(columns={'Time': 't'})
ef = ef.rename(columns={'Angle': 'a'})
ef=ef[(ef.t>16)]
plt.plot(ef.t,ef.a)
plt.grid()

# %%
def sinFit(t,omega,phi,A,offset):
    return A*np.sin(omega*t + phi) + offset

sig=np.ones(len(ef))*360.0/2048  # error in angle
T=1.8
omega0 = 2*np.pi/T
A0=70
phi0=0.0
offset0=0.0

par, cov = curve_fit(sinFit, ef.t, ef.a, p0=(omega0,phi0,A0,offset0), sigma=sig)

omega,phi,A,offset = par
dOmega, dPhi, dA, dOffset = np.sqrt(np.diag(cov))

plt.plot(ef.t, ef.a, 'b+')
plt.plot(ef.t, sinFit(ef.t, omega, phi, A, offset),'r-')
plt.title("Relationship between time and an amplitude of 20")
plt.ylabel("amplitude")
plt.xlabel("period")
print("Omega = %4.4f +/- %4.4f" % (omega, dOmega))
print("phi = %4.2f +/- %4.2f" % (phi, dPhi))
print("A = %4.2f +/- %4.2f" % (A, dA))
print("offset = %4.2f +/- %4.2f" % (offset, dOffset))
# Out:
# Omega = 3.3114 +/- 0.0002
# phi = 4.15 +/- 0.01
# A = 48.11 +/- 0.04
# offset = -0.21 +/- 0.03

# %%
ff=pd.read_csv('Pend60degrees.csv')
ff.head()
# Out:
#     Time  Angle
# 0  3.002    0.0
# 1  3.003    0.0
# 2  3.004    0.0
# 3  3.005    0.0
# 4  3.006    0.0

# %%
ff = ff.rename(columns={'Time': 't'})
ff = ff.rename(columns={'Angle': 'a'})
ff= ff[(ff.t>16)]
plt.plot(ff.t,ff.a)
plt.grid()

# %%
def sinFit(t,omega,phi,A,offset):
    return A*np.sin(omega*t + phi) + offset

sig=np.ones(len(ff))*360.0/2048  # error in angle
T=1.8
omega0 = 2*np.pi/T
A0=70
phi0=0.0
offset0=0.0
par, cov = curve_fit(sinFit, ff.t, ff.a, p0=(omega0,phi0,A0,offset0), sigma=sig)

omega,phi,A,offset = par
dOmega, dPhi, dA, dOffset = np.sqrt(np.diag(cov))

plt.plot(ff.t, ff.a, 'b+')
plt.plot(ff.t, sinFit(ff.t, omega, phi, A, offset),'r-')
plt.title("Relationship between time and an amplitude of 20")
plt.ylabel("amplitude")
plt.xlabel("period")
print("Omega = %4.4f +/- %4.4f" % (omega, dOmega))
print("phi = %4.2f +/- %4.2f" % (phi, dPhi))
print("A = %4.2f +/- %4.2f" % (A, dA))
print("offset = %4.2f +/- %4.2f" % (offset, dOffset))
# Out:
# Omega = 3.2440 +/- 0.0005
# phi = 4.99 +/- 0.01
# A = 56.81 +/- 0.04
# offset = 0.70 +/- 0.03

# %%
gf=pd.read_csv('Pend60degrees.csv')
gf.head()
# Out:
#     Time  Angle
# 0  3.002    0.0
# 1  3.003    0.0
# 2  3.004    0.0
# 3  3.005    0.0
# 4  3.006    0.0

# %%
gf = gf.rename(columns={'Time': 't'})
gf = gf.rename(columns={'Angle': 'a'})
gf=gf[(gf.t>16)]
plt.plot(gf.t,gf.a)
plt.grid()

# %%
def sinFit(t,omega,phi,A,offset):
    return A*np.sin(omega*t + phi) + offset

sig=np.ones(len(gf))*360.0/2048  # error in angle
T=1.8
omega0 = 2*np.pi/T
A0=70
phi0=0.0
offset0=0.0
par, cov = curve_fit(sinFit, gf.t, gf.a, p0=(omega0,phi0,A0,offset0), sigma=sig)

omega,phi,A,offset = par
dOmega, dPhi, dA, dOffset = np.sqrt(np.diag(cov))

plt.plot(gf.t, gf.a, 'b+')
plt.plot(gf.t, sinFit(ff.t, omega, phi, A, offset),'r-')
plt.title("Relationship between time and an amplitude of 20")
plt.ylabel("amplitude")
plt.xlabel("period")
print("Omega = %4.4f +/- %4.4f" % (omega, dOmega))
print("phi = %4.2f +/- %4.2f" % (phi, dPhi))
print("A = %4.2f +/- %4.2f" % (A, dA))
print("offset = %4.2f +/- %4.2f" % (offset, dOffset))
# Out:
# Omega = 3.2440 +/- 0.0005
# phi = 4.99 +/- 0.01
# A = 56.81 +/- 0.04
# offset = 0.70 +/- 0.03

# %%
famp=pd.read_csv('ang_f_and_amp.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-296-7435d71a8aa6> in <module>
# ----> 1 famp=pd.read_csv('ang_f_and_amp.csv')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'ang_f_and_amp.csv' does not exist

# %%
g = 9.8
l = 0.592
omega1 = np.sqrt(g/l)
ampr = (amp/180)*np.pi
t0 = (2*np.pi)/omega1
t = (2*np.pi)/freq
T1 = 1 +((ampr**2)/16)
T2 = t/t0
T3 = 1 *np.ones(len(ampr)) 

def simpson(f, a, b, N, args=None):
    if args is None:
        args=[]
    x=np.linspace(a,b,2*N)  # sample the function
    h=(b-a)/(2*N-1)
    y=f(*([x] +list(args)))
    evens =  y[2:-2:2]
    odds = y[1:-1:2]
    return (y[0] + y[-1] + 2*odds.sum() + 4*evens.sum())*h/3.0

def K_int(phi, m):
    return 1.0/np.sqrt(1-m*np.sin(phi)**2)

def K(m, N=1000):
    return simpson(K_int, 0, np.pi/2, N=N, args=(m,))

sraList=[]
for theta in ampr:
    sraList.append(2*K(np.sin(theta/2.0)**2)/np.pi)

plt.title("-")
plt.xlabel("-")
plt.ylabel("T/To")
plt.plot(amp,T1,'b.', label="experiment")
plt.plot(amp,T2,'r-', label="small angle approx.")
plt.plot(amp,T3,'g-', label="very small angle approx.")
plt.plot(amp,sraList,'c-', label="exact theory")
#plot(thDeg, vsaa, 'g-', label="very small angle approx.")
#plot(thDeg, sraList, 'c-', label="exact theory")
plt.legend(loc=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-254-e018b2777839> in <module>
#       2 l = 0.592
#       3 omega1 = np.sqrt(g/l)
# ----> 4 ampr = (amp/180)*np.pi
#       5 t0 = (2*np.pi)/omega1
#       6 t = (2*np.pi)/freq
#
# NameError: name 'amp' is not defined
