# %%
from LightPipes import *
import matplotlib.pyplot as plt
import numpy as np
wavelength=169*um
size=25.0*mm
N=2000
N2=int(N/2)
z=10*cm
d=3000*mm
f=2*cm
F=Begin(size,wavelength,N)
F=CircAperture(d/2, 0, 0, F)
F=Fresnel(F,z)
I1=Intensity(F)
F=Lens(F,f)
F=Forvard(f,F)
I=Intensity(0,F)

s1 =    r'LightPipes for Python' + '\n'
s2 =    r'RoundHole.py'+ '\n\n'\
        f'size = {size/mm:4.2f} mm' + '\n'\
        f'$\lambda$ = {wavelength/um:4.2f} $\mu$m' + '\n'\
        f'N = {N:d}' + '\n' +\
        f'f = {f/cm:4.2f} cm focal length' + '\n'\
        f'd = {d/mm:4.2f} mm hole diameter' + '\n'\
        f'z = {z/cm:4.2f} cm distance from hole to lens' + '\n'\
        r'${\copyright}$ Fred van Goor, February 2021'

fig=plt.figure(figsize=(11,6))
fig.suptitle("Diffraction from a round hole")
ax1 = fig.add_subplot(221);ax1.axis('off')
ax2 = fig.add_subplot(222);ax2.axis('off')
ax3 = fig.add_subplot(223);ax3.axis('off')
ax4 = fig.add_subplot(224)
#ax1.set_title(f'Intensity pattern after {z/cm:4.1f} cm propagation')
#ax1.imshow(I1,cmap='jet')
ax2.set_xlim(N2-50,N2+50)
ax2.set_ylim(N2-50,N2+50)
ax2.set_title('Intensity pattern at the focus of the lens')
ax2.imshow(I,cmap='jet')
ax3.text(0.0,1.0,s1,fontsize=12, fontweight='bold')
ax3.text(0.0,0.3,s2)
X=np.linspace(-size/2,size/2,N)
ax4.plot(X/mm,I[N2]); ax4.set_xlabel('x[mm]'); ax4.set_ylabel('Intensity [a.u.]')
ax4.set_xlim(-1,1)
plt.show()

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\ramaz\appdata\roaming\python\python37\site-packages (21.0)
# Collecting pip
#   Downloading pip-21.1-py3-none-any.whl (1.5 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 21.0
#     Uninstalling pip-21.0:
#       Successfully uninstalled pip-21.0
#   Rolling back uninstall of pip
#   Moving to c:\users\ramaz\appdata\roaming\python\python37\scripts\pip.exe
#    from C:\Users\ramaz\AppData\Local\Temp\pip-uninstall-c65qauyh\pip.exe
#   Moving to c:\users\ramaz\appdata\roaming\python\python37\scripts\pip3.7.exe
#    from C:\Users\ramaz\AppData\Local\Temp\pip-uninstall-c65qauyh\pip3.7.exe
#   Moving to c:\users\ramaz\appdata\roaming\python\python37\scripts\pip3.exe
#    from C:\Users\ramaz\AppData\Local\Temp\pip-uninstall-c65qauyh\pip3.exe
#   Moving to c:\users\ramaz\appdata\roaming\python\python37\site-packages\pip-21.0.dist-info\
#    from c:\users\ramaz\appdata\roaming\python\python37\site-packages\~ip-21.0.dist-info
#   Moving to c:\users\ramaz\appdata\roaming\python\python37\site-packages\pip\
#    from c:\users\ramaz\appdata\roaming\python\python37\site-packages\~ip
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\ProgramData\\Anaconda3\\Lib\\site-packages\\pip\\__init__.py'
# Consider using the `--user` option or check the permissions.
#
# WARNING: You are using pip version 21.0; however, version 21.1 is available.
# You should consider upgrading via the 'C:\ProgramData\Anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
from LightPipes import *
import matplotlib.pyplot as plt
import numpy as np
wavelength=161e-9
size=25.0
N=2000
N2=int(N/2)
z=6,1712e+19
d=3
f=6,1712e+19
F=Begin(size,wavelength,N)
F=CircAperture(d/2, 0, 0, F)
F=Fresnel(F,z)
I1=Intensity(F)
F=Lens(F,f)
F=Forvard(f,F)
I=Intensity(0,F)

s1 =    r'LightPipes for Python' + '\n'
s2 =    r'RoundHole.py'+ '\n\n'\
        f'size = {size/mm:4.2f} mm' + '\n'\
        f'$\lambda$ = {wavelength/um:4.2f} $\mu$m' + '\n'\
        f'N = {N:d}' + '\n' +\
        f'f = {f/cm:4.2f} cm focal length' + '\n'\
        f'd = {d/mm:4.2f} mm hole diameter' + '\n'\
        f'z = {z/cm:4.2f} cm distance from hole to lens' + '\n'\
        r'${\copyright}$ Fred van Goor, February 2021'

fig=plt.figure(figsize=(11,6))
fig.suptitle("Diffraction from a round hole")
ax1 = fig.add_subplot(221);ax1.axis('off')
ax2 = fig.add_subplot(222);ax2.axis('off')
ax3 = fig.add_subplot(223);ax3.axis('off')
ax4 = fig.add_subplot(224)
ax1.set_title(f'Intensity pattern after {z/cm:4.1f} cm propagation')
ax1.imshow(I1,cmap='jet')
ax2.set_xlim(N2-50,N2+50)
ax2.set_ylim(N2-50,N2+50)
ax2.set_title('Intensity pattern at the focus of the lens')
ax2.imshow(I,cmap='jet')
ax3.text(0.0,1.0,s1,fontsize=12, fontweight='bold')
ax3.text(0.0,0.3,s2)
X=np.linspace(-size/2,size/2,N)
ax4.plot(X/mm,I[N2]); ax4.set_xlabel('x[mm]'); ax4.set_ylabel('Intensity [a.u.]')
ax4.set_xlim(-1,1)
plt.show()

# %%
from LightPipes import *
import matplotlib.pyplot as plt

Field=Begin(20*mm, 170*um, 256)
Field = CircAperture(5*mm, 0, 0, Field)
Field = Forvard(1*m, Field)
I = Intensity(0,Field)

x=[]
for i in range(256):
    x.append((-20*mm/2+i*20*mm/256)/mm)

fig=plt.figure(figsize=(15,6))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
ax1.imshow(I,cmap='rainbow'); ax1.axis('off')
ax2.plot(x,I[128]);ax2.set_xlabel('x [mm]');ax2.set_ylabel('Intensity [a.u.]')
ax2.grid('on')
plt.show()

# %%
174
104
200
129
