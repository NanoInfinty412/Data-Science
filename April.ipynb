# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x1 = np.fromfile('ra_test_data.dat',np.float32)
x2 = np.fromfile('ra_test_data2.dat',np.float32)
x3 = np.fromfile('ra_test_data3.dat',np.float32)
x4 = np.fromfile('ra_test_data4.dat',np.float32)
x5 = np.fromfile('ra_test_data5.dat',np.float32)

# %%
t = np.arange(len(x1))
plt.plot(t,x1[2292000:2297000],'.')
#plt.plot(x)
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-938487993c53> in <module>
#       1 t = np.arange(len(x1))
# ----> 2 plt.plot(t,x1[2292000:2297000],'.')
#       3 #plt.plot(x)
#       4 plt.grid()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
# ...

# %%
t2 = np.arange(len(x2))
plt.plot(t2,x2,'.')
#plt.plot(x)
plt.grid()

# %%
t3 = np.arange(len(x3))
plt.plot(x3,'.')
#plt.plot(x)
plt.grid()

# %%
t4 = np.arange(len(x4))
plt.plot(x4,'.')
#plt.plot(x)
plt.grid()

# %%
t5 = np.arange(len(x5))
plt.plot(x5,'-')
#plt.plot(x)
plt.grid()
